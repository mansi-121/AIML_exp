# %% [markdown]
# <a href="https://colab.research.google.com/github/mansi-121/AIML_exp/blob/main/experiment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab3cab35-0e35-469b-b043-5bc75ce39779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab3cab35-0e35-469b-b043-5bc75ce39779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

# Open the zip file
with zipfile.ZipFile('business-employment-data-Jun-2024-quarter.zip', 'r') as z:

    # Load the specific CSV file from the zip into a pandas DataFrame
    with z.open('machine-readable-business-employment-data-Jun-2024-quarter.csv') as f:
        data = pd.read_csv(f)

# %%
import io

# %% [markdown]
# no. of rows and columns

# %%
data.shape
# Out:
# (23350, 14)

# %% [markdown]
# first five rows of the dataset

# %%
data.head(5)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %% [markdown]
# size of the dataset

# %%
data.size
# Out:
# 326900

# %% [markdown]
# no. of missing values

# %%
data.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           2839
# Suppressed          20511
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      23350
# Series_title_5      23350
# dtype: int64

# %% [markdown]
# sum from the numerical columns.

# %%
data.select_dtypes(include='number').sum()
# Out:
# Period            4.710246e+07
# Data_value        1.495185e+09
# Magnitude         5.374200e+04
# Series_title_4    0.000000e+00
# Series_title_5    0.000000e+00
# dtype: float64

# %% [markdown]
# calculating average

# %%
data.select_dtypes(include='number').mean()
# Out:
# Period             2017.236176
# Data_value        72896.735258
# Magnitude             2.301585
# Series_title_4             NaN
# Series_title_5             NaN
# dtype: float64

# %% [markdown]
# min and max

# %%
data.select_dtypes(include='number').min()
# Out:
# Period            2011.060000
# Data_value           1.187001
# Magnitude            0.000000
# Series_title_4            NaN
# Series_title_5            NaN
# dtype: float64

# %%
data.select_dtypes(include='number').max()
# Out:
# Period               2024.06
# Data_value        2321295.00
# Magnitude               6.00
# Series_title_4           NaN
# Series_title_5           NaN
# dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')
